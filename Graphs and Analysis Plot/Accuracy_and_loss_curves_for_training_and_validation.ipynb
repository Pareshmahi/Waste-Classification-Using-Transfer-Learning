# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
models_history = {
    "ResNet-50": {
        "train_acc": [0.78, 0.87, 0.90, 0.92, 0.93, 0.94, 0.94, 0.95, 0.95, 0.95, 0.96, 0.96, 0.96, 0.96, 0.96, 0.97],  # Replace with actual values
        "val_acc": [0.86, 0.87, 0.89, 0.88, 0.89, 0.89, 0.90, 0.90, 0.90, 0.88, 0.90, 0.90, 0.90, 0.88, 0.89, 0.89],
        "train_loss": [0.62, 0.36, 0.27, 0.23, 0.19, 0.16, 0.16, 0.14, 0.12, 0.12, 0.11, 0.10, 0.09, 0.11, 0.09, 0.8],
        "val_loss": [0.40, 0.35, 0.37, 0.38, 0.35, 0.37, 0.34, 0.34, 0.37, 0.42, 0.34, 0.38, 0.37, 0.45, 0.39, 0.40]
    },
    "ResNet-34": {
        "train_acc": [0.78, 0.86, 0.90, 0.92, 0.93, 0.93, 0.94, 0.96, 0.95],  # Replace with actual values
        "val_acc": [0.85, 0.86, 0.88, 0.89, 0.87, 0.88, 0.89, 0.87, 0.89],
        "train_loss": [0.63, 0.38, 0.28, 0.21, 0.19, 0.18, 0.15, 0.12, 0.15],
        "val_loss": [0.43, 0.39, 0.37, 0.36, 0.41, 0.36, 0.37, 0.44, 0.38]
    },
    "DenseNet-121": {
        "train_acc": [0.78, 0.89, 0.82, 0.93, 0.95, 0.95, 0.96, 0.96, 0.97, 0.97, 0.97],  # Replace with actual values
        "val_acc": [0.86, 0.90, 0.90, 0.91, 0.90, 0.91, 0.91, 0.90, 0.91, 0.91, 0.91],
        "train_loss": [0.64, 0.32, 0.22, 0.18, 0.14, 0.12, 0.09, 0.08, 0.08, 0.07, 0.06],
        "val_loss": [0.30, 0.30, 0.27, 0.93, 0.30, 0.29, 0.28, 0.32, 0.33, 0.31, 0.32]
    },
    "EfficientNet-B0": {
        "train_acc": [0.73, 0.87, 0.91, 0.93, 0.94, 0.95, 0.96, 0.96, 0.97, 0.97, 0.97, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98, 0.98],  # Replace with actual values
        "val_acc": [0.88, 0.90, 0.91, 0.92, 0.92, 0.92, 0.92, 0.92, 0.91, 0.92, 0.92, 0.92, 0.93, 0.93, 0.92, 0.92, 0.93, 0.92],
        "train_loss": [0.82, 0.38, 0.26, 0.20, 0.16, 0.13, 0.10, 0.10, 0.08, 0.07, 0.06, 0.06, 0.05, 0.05, 0.05, 0.04, 0.04, 0.04],
        "val_loss": [0.37, 0.30, 0.27, 0.23, 0.25, 0.26, 0.26, 0.27, 0.29, 0.28, 0.30, 0.29, 0.28, 0.28, 0.30, 0.31, 0.31, 0.31]
    },
    "EfficientNet-B3": {
        "train_acc": [0.75, 0.89, 0.92, 0.95, 0.96, 0.96, 0.97, 0.97, 0.98, 0.98, 0.98],  # Replace with actual values
        "val_acc": [0.89, 0.92, 0.93, 0.94, 0.93, 0.94, 0.93, 0.93, 0.94, 0.94, 0.94],
        "train_loss": [0.76, 0.30, 0.12, 0.14, 0.11, 0.09, 0.07, 0.06, 0.05, 0.05, 0.05],
        "val_loss": [0.32, 0.23, 0.22, 0.19, 0.20, 0.19, 0.21, 0.21, 0.20, 0.21, 0.20]
    },
    "Inception-V3": {
        "train_acc": [0.81, 0.90, 0.94, 0.95, 0.95, 0.96, 0.96, 0.97, 0.97, 0.97],  # Replace with actual values
        "val_acc": [0.89, 0.91, 0.91, 0.91, 0.92, 0.91, 0.91, 0.92, 0.91, 0.91],
        "train_loss": [0.57, 0.27, 0.18, 0.13, 0.11, 0.09, 0.09, 0.08, 0.07, 0.07],
        "val_loss": [0.32, 0.27, 0.27, 0.12, 0.26, 0.28, 0.31, 0.29, 0.31, 0.32]
    },
    "MobileNet-V2": {
        "train_acc": [0.76, 0.86, 0.89, 0.91, 0.93, 0.94, 0.94, 0.95, 0.96, 0.96, 0.96, 0.96, 0.97, 0.97, 0.97],  # Replace with actual values
        "val_acc": [0.85, 0.87, 0.88, 0.89, 0.90, 0.89, 0.89, 0.90, 0.89, 0.91, 0.90, 0.90, 0.89, 0.91, 0.89],
        "train_loss": [0.67, 0.39, 0.30, 0.24, 0.19, 0.16, 0.14, 0.13, 0.11, 0.09, 0.10, 0.09, 0.08, 0.08, 0.07],
        "val_loss": [0.43, 0.35, 0.34, 0.34, 0.31, 0.34, 0.35, 0.34, 0.37, 0.33, 0.38, 0.37, 0.40, 0.36, 0.40]
    },
    "VGG16": {
        "train_acc": [0.72, 0.83, 0.87, 0.90, 0.91, 0.92, 0.93, 0.94, 0.94, 0.95, 0.96, 0.95, 0.95, 0.96, 0.96, 0.96],  # Replace with actual values
        "val_acc": [0.82, 0.84, 0.83, 0.86, 0.84, 0.84, 0.88, 0.87, 0.86, 0.88, 0.89, 0.88, 0.86, 0.89, 0.87, 0.88],
        "train_loss": [0.79, 0.48, 0.37, 0.29, 0.26, 0.21, 0.20, 0.17, 0.15, 0.14, 0.12, 0.13, 0.12, 0.11, 0.11, 0.10],
        "val_loss": [0.53, 0.47, 0.52, 0.44, 0.51, 0.50, 0.41, 0.47, 0.53, 0.48, 0.49, 0.44, 0.55, 0.50, 0.52, 0.48]
    },
    # Add remaining models here...
}

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define distinct colors for each model
colors = [
    "b", "g", "r", "c", "m", "y", "k", "#FF5733"
]  # 8 unique colors

plt.figure(figsize=(12, 6))

# Plot accuracy for each model
for i, (model, data) in enumerate(models_history.items()):
    epochs = range(1, len(data["train_acc"]) + 1)
    plt.plot(epochs, data["train_acc"], linestyle="dashed", color=colors[i], label=f"{model} - Train")
    plt.plot(epochs, data["val_acc"], color=colors[i], label=f"{model} - Val")

plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Training vs. Validation Accuracy for All Models")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))

# Plot loss for each model
for i, (model, data) in enumerate(models_history.items()):
    epochs = range(1, len(data["train_loss"]) + 1)
    plt.plot(epochs, data["train_loss"], linestyle="dashed", color=colors[i], label=f"{model} - Train")
    plt.plot(epochs, data["val_loss"], color=colors[i], label=f"{model} - Val")

plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training vs. Validation Loss for All Models")
plt.legend()
plt.grid(True)
plt.show()
